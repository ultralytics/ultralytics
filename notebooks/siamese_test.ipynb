# %%
import matplotlib.pyplot as plt
from debugpy.launcher import channel


from ultralytics_MB import YOLO 
model = YOLO("yolov9es.yaml",task="detect")
# Out:
# WARNING ⚠️ YOLOv9 `Silence` module is deprecated in favor of nn.Identity. Please delete local *.pt file and re-download the latest model checkpoint.
# ch = 6
# zeroes shape: torch.Size([1, 6, 256, 256])
# model Detect(
#   (cv2): ModuleList(
#     (0): Sequential(
#       (0): Conv(
#         (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1-2): 2 x Sequential(
#       (0): Conv(
#         (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
model.model.model[]
# Out:
# Input()

# %%
model.train(data="/home/clanger/HeiGIT/sketch_map_tool/notebooks/results/siamese_test/data.yaml",channels=6,imgsz=1024,batch=1,adjust_layers=[],single_cls=True,dual_stream=True,task="detect")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.train(data="/home/clanger/HeiGIT/sketch_map_tool/notebooks/results/siamese_test/data.yaml",channels=6,imgsz=1024,batch=1,adjust_layers=[],single_cls=True,dual_stream=True,task="detect")
#
# NameError: name 'model' is not defined

# %%
model = YOLO("yolov8n.pt",task="detect")
model.train(data="/home/clanger/HeiGIT/sketch_map_tool/notebooks/results/dual_stream_test/data.yaml",channels=6,imgsz=256,batch=1,adjust_layers=[0],dual_stream=True,task="detect")
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.14 torch-2.3.0+cu121 CPU (Intel Core(TM) i7-8550U 1.80GHz)
# ...

# %%
model = YOLO("yolov9e.yaml")
model.train(data="/home/clanger/HeiGIT/sketch_map_tool/notebooks/results/dual_stream_test/data.yaml",channels=6,imgsz=240,batch=1,adjust_layers=[1,15],dual_stream=True,task="detect")
# Out:
# ch = 3
# zeroes shape: torch.Size([1, 3, 256, 256])
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.14 torch-2.3.0+cu121 CPU (Intel Core(TM) i7-8550U 1.80GHz)
# ...

# %%
model = YOLO("yolov9e.yaml")
# Out:
# ch = 3
# zeroes shape: torch.Size([1, 3, 256, 256])

# %%
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Identity()
#       (1): Conv(
#         (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (3): RepNCSPELAN4(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Sequential(
#           (0): RepCSP(
#             (cv1): Conv(
# ...

# %%
import matplotlib.pyplot as plt
img
# Out:
# array([[[ 49,  55, 165, 222, 222, 224],
#         [ 49,  55, 165, 222, 222, 224],
#         [ 49,  55, 165, 222, 222, 224],
#         ...,
#         [150, 171, 225, 118, 118, 118],
#         [150, 171, 225, 118, 118, 118],
#         [150, 171, 225,  55,  55,  55]],
#
#        [[ 48,  55, 165, 222, 222, 224],
#         [ 49,  55, 165, 222, 222, 224],
#         [ 49,  55, 165, 222, 222, 224],
#         ...,
#         [150, 171, 225, 255, 255, 255],
#         [150, 171, 225, 255, 255, 255],
#         [150, 171, 225, 119, 119, 119]],
#
#        [[ 48,  55, 165, 222, 222, 224],
#         [ 48,  55, 165, 222, 222, 224],
#         [ 48,  55, 165, 222, 222, 224],
#         ...,
#         [150, 171, 225, 255, 255, 255],
#         [150, 171, 225, 255, 255, 255],
#         [150, 171, 225, 119, 119, 119]],
#
#        ...,
#
#        [[149, 168, 223, 232, 238, 241],
#         [149, 168, 223, 232, 238, 241],
#         [149, 168, 223, 232, 238, 241],
#         ...,
# ...

# %%
import cv2

img_cv = cv2.imread("/home/clanger/HeiGIT/sketch_map_tool/notebooks/results/cropped_augmented/2_0e7225d8-c8e1-11ee-b0c1-1856806de7cd.png")

# %%
plt.imshow(img[0][:,:,::-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.imshow(img[0][:,:,::-1])
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
img_cv.shape
# Out:
# (1587, 1867, 3)

# %%
plt.imshow(img_cv)

# %%
img.shape
# Out:
# (1587, 1867, 6)

# %%
img_cv.shape
# Out:
# (1587, 1867, 3)

# %%
#plot first bands of image
plt.imshow(img[:,:,0])

# %%
plt.imshow(img_cv[:,:,0])
