# %%
# !yolo train data=coco128.yaml model=yolov8n.pt epochs=2 batch=64 imgsz=320
# Out:
# ...
# Ultralytics YOLOv8.1.2 🚀 Python-3.8.10 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16384MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # initialize
results = model.train(data='coco128.yaml', model='yolov8n.pt', epochs=2, batch=64, imgsz=320)
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.8.10 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16384MiB)
# ...
